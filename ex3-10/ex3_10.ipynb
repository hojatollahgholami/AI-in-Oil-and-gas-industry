# %% [markdown]
# <a href="https://colab.research.google.com/github/hojatollahgholami/AI-in-Oil-and-gas-industry/blob/main/ex39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# در این مثال داده های ۲۵ سنسور از کم\رسور گریز از مرکز مربوط به یکسال برای مدلسازی ناهنجاری استفاده می شود.

# %% [markdown]
# برای اجرای مدل سازی از دستور در ترمینال استفاده می شود.

# %%
python3 ex39_model.py

# %% [markdown]
# س\س با استافاده از fastAPI برای اجرای مدل استفاده می شود

# %%
python3 ex39_app.py

# %% [markdown]
# بدلیل نبود دیتای سنسورهاُ از داده مصنوعی استفاده می شود.

# %%
python3 ex39_monitoring.py
